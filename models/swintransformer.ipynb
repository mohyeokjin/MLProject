# %%
import torch
import torchvision.transforms as T
from timm import create_model
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
import yaml
import os

class FaceDataset(Dataset):
    def __init__(self, data_folder, model, transform=None):
        self.data_folder = data_folder
        self.model = model  # 모델 추가
        self.image_folder = ImageFolder(os.path.join(data_folder, 'images'), transform=transform)
        self.face_coordinates = self.load_face_coordinates()

    def load_face_coordinates(self):
        face_coordinates = []  # 얼굴 좌표 정보를 저장할 리스트
        labels_folder = os.path.join(self.data_folder, 'labels')

        for path, _ in self.image_folder.samples:
            # 이미지 파일의 경로를 기반으로 얼굴 좌표 파일의 경로를 구성
            image_name = os.path.basename(path)
            face_txt_path = os.path.join(labels_folder, image_name.replace('.jpg', '.txt'))

            # 얼굴 좌표 파일이 실제로 존재하는지 확인
            if os.path.exists(face_txt_path):
                with open(face_txt_path, 'r') as f:
                    # txt 파일에서 얼굴 좌표 정보를 읽어옴
                    line = f.readline().strip().split()

                    if len(line) != 5:
                        print(f"파일이 없습니다 : {face_txt_path}")
                        continue

                    x, y, size_x, size_y = map(float, line[1:])
                    x_scaled = x / center_size
                    y_scaled = y / center_size

                    face_coords = [x_scaled, y_scaled, size_x, size_y]
                    face_coordinates.append(face_coords)
            else:
                print(f"파일이 없습니다 : {image_name}")

        return face_coordinates
    def __getitem__(self, index):
        image, label_tensor = self.image_folder[index]

        if not isinstance(label_tensor, (int, float)):
            label = label_tensor.item()
        else:
            label = label_tensor

        image_np = image.permute(1, 2, 0).numpy() 
        H, W, _ = image_np.shape  

        print(f"Original Image size: ({H}, {W}, 3)")

        face_coords = self.face_coordinates[index]

        resized_image = T.functional.resize(image, (300, 300))  
        resized_H, resized_W = resized_image.shape[1:3]

        x_scaled, y_scaled, size_x_scaled, size_y_scaled = face_coords
        x_scaled = int(x_scaled * resized_W)
        y_scaled = int(y_scaled * resized_H)
        size_x_scaled = int(size_x_scaled * resized_W)
        size_y_scaled = int(size_y_scaled * resized_H)

        # 보정: crop 영역의 크기가 0이 되지 않도록 처리
        size_x_scaled = max(size_x_scaled, 1)
        size_y_scaled = max(size_y_scaled, 1)

        face_img = T.functional.crop(resized_image, top=y_scaled, left=x_scaled, height=size_y_scaled, width=size_x_scaled)

        resized_face_img = T.functional.resize(face_img, (224, 224)) # swin transformer 모델의 이미지 크기에 맞게 변환

        print(f"얼굴 좌표값 : {face_coords}")
        print(f"label : {label}")

        return resized_image, resized_face_img, face_coords, label


    def __len__(self):
        return len(self.image_folder)

# yaml 파일 로드
with open('./data.yaml', 'r', encoding='UTF8') as f:
    config = yaml.safe_load(f)

# center_size 설정
center_size = config.get('img_size', 1.0)

# Swin Transformer 모델
swin_model = create_model('swin_base_patch4_window7_224', pretrained=True, num_classes=1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
swin_model.to(device)

# 데이터 전처리
print(swin_model.default_cfg['input_size'])
transform = T.Compose([T.ToTensor()])
face_dataset = FaceDataset('./PJT_MCL/train', model=swin_model, transform=transform)
dataloader = DataLoader(face_dataset, batch_size=4, shuffle=True, num_workers=0)

optimizer = torch.optim.AdamW(swin_model.parameters(), lr=1e-4)
criterion = torch.nn.BCEWithLogitsLoss()

for epoch in range(10):
    for resized_images, face_images, face_coords, labels in dataloader:
        resized_images = resized_images.to(device)
        face_images = face_images.to(device)

        print(f"얼굴 좌표값(훈련) : {face_coords}")

        # face_coords가 리스트이므로 각각의 요소를 Tensor로 변환
        face_coords = [coord.to(device) for coord in face_coords]

        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = swin_model(face_images)
        print(f"결과값 : {outputs}")

        labels = labels.unsqueeze(1).float()  # 모델 출력의 크기와 일치하도록 차원 추가 및 float로 변환
        print(f"labels : {labels}")

        loss = criterion(outputs, labels) 
        print(f"loss : {loss}")

        loss.backward()
        optimizer.step()

torch.save(swin_model.state_dict(), 'swin_model_ver3.pt')
# Out:
# (3, 224, 224)
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014333333333333333, 0.0010666666666666667, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0022444444444444443, 1.1111111111111112e-05, 0.07666666666666666, 0.07666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021, 0.00043333333333333337, 0.12666666666666668, 0.12666666666666668]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0022, 0.00024444444444444443, 0.023333333333333334, 0.023333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0014, 0.0022, 0.0021, 0.0022], dtype=torch.float64), tensor([1.0667e-03, 1.1111e-05, 4.3333e-04, 2.4444e-04], dtype=torch.float64), tensor([0.0367, 0.0767, 0.1267, 0.0233], dtype=torch.float64), tensor([0.0367, 0.0767, 0.1267, 0.0233], dtype=torch.float64)]
# 결과값 : tensor([[0.0199],
#         [0.1223],
#         [0.1880],
#         [0.1685]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.7579546570777893
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001011111111111111, 5.555555555555555e-05, 0.05, 0.05]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007555555555555555, 0.0010666666666666667, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015444444444444444, 0.0013777777777777777, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017666666666666668, 0.001688888888888889, 0.056666666666666664, 0.056666666666666664]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0010, 0.0008, 0.0015, 0.0018], dtype=torch.float64), tensor([5.5556e-05, 1.0667e-03, 1.3778e-03, 1.6889e-03], dtype=torch.float64), tensor([0.0500, 0.0433, 0.0300, 0.0567], dtype=torch.float64), tensor([0.0500, 0.0433, 0.0300, 0.0567], dtype=torch.float64)]
# 결과값 : tensor([[-0.9645],
#         [-0.8461],
#         [-1.0353],
#         [-1.1928]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.31220585107803345
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002033333333333333, 0.0021222222222222224, 0.19666666666666666, 0.19666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0030444444444444442, 0.0015999999999999999, 0.02, 0.02]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0023888888888888887, 0.0011222222222222222, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015555555555555557, 0.0010777777777777778, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0020, 0.0030, 0.0024, 0.0016], dtype=torch.float64), tensor([0.0021, 0.0016, 0.0011, 0.0011], dtype=torch.float64), tensor([0.1967, 0.0200, 0.0267, 0.0267], dtype=torch.float64), tensor([0.1967, 0.0200, 0.0267, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-1.8095],
#         [-2.4641],
#         [-4.4775],
#         [-1.5264]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.11030972748994827
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018999999999999998, 0.0012777777777777779, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007333333333333333, 0.0016222222222222224, 0.08, 0.08]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012222222222222222, 0.0004555555555555555, 0.04, 0.04]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002033333333333333, 0.0009777777777777777, 0.2733333333333333, 0.2733333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0019, 0.0007, 0.0012, 0.0020], dtype=torch.float64), tensor([0.0013, 0.0016, 0.0005, 0.0010], dtype=torch.float64), tensor([0.0367, 0.0800, 0.0400, 0.2733], dtype=torch.float64), tensor([0.0367, 0.0800, 0.0400, 0.2733], dtype=torch.float64)]
# 결과값 : tensor([[-3.0247],
#         [-2.7515],
#         [-4.0307],
#         [-3.1364]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.04235882684588432
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015222222222222221, 0.0015333333333333334, 0.04666666666666667, 0.04666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0010333333333333334, 0.0015666666666666665, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002322222222222222, 0.0009333333333333334, 0.04, 0.04]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016555555555555555, 0.0015333333333333334, 0.03333333333333333, 0.03333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0015, 0.0010, 0.0023, 0.0017], dtype=torch.float64), tensor([0.0015, 0.0016, 0.0009, 0.0015], dtype=torch.float64), tensor([0.0467, 0.0267, 0.0400, 0.0333], dtype=torch.float64), tensor([0.0467, 0.0267, 0.0400, 0.0333], dtype=torch.float64)]
# 결과값 : tensor([[-4.7107],
#         [-8.3541],
#         [-4.1646],
#         [-4.0737]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.01037021353840828
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018888888888888887, 0.0011555555555555555, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0008444444444444445, 0.0008333333333333334, 0.05, 0.05]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0019666666666666665, 0.0033222222222222225, 0.09, 0.09]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0005666666666666667, 0.0015444444444444444, 0.05333333333333334, 0.05333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0019, 0.0008, 0.0020, 0.0006], dtype=torch.float64), tensor([0.0012, 0.0008, 0.0033, 0.0015], dtype=torch.float64), tensor([0.0633, 0.0500, 0.0900, 0.0533], dtype=torch.float64), tensor([0.0633, 0.0500, 0.0900, 0.0533], dtype=torch.float64)]
# 결과값 : tensor([[-7.5047],
#         [-5.1820],
#         [-5.2458],
#         [-8.1190]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.002926184795796871
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015777777777777778, 0.0013666666666666666, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.000911111111111111, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0024666666666666665, 0.0013, 0.04666666666666667, 0.04666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0027333333333333333, 9.999999999999999e-05, 0.05333333333333334, 0.05333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0016, 0.0025, 0.0027], dtype=torch.float64), tensor([1.3667e-03, 9.1111e-04, 1.3000e-03, 1.0000e-04], dtype=torch.float64), tensor([0.0367, 0.0533, 0.0467, 0.0533], dtype=torch.float64), tensor([0.0367, 0.0533, 0.0467, 0.0533], dtype=torch.float64)]
# 결과값 : tensor([[ -7.7271],
#         [-10.6356],
#         [-10.2231],
#         [ -7.3385]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.00028772372752428055
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016222222222222224, 0.0012444444444444445, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015777777777777778, 0.0012777777777777779, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017444444444444443, 0.0013777777777777777, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0001111111111111111, 0.0008222222222222222, 0.043333333333333335, 0.043333333333333335]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0016, 0.0017, 0.0001], dtype=torch.float64), tensor([0.0012, 0.0013, 0.0014, 0.0008], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0367, 0.0433], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0367, 0.0433], dtype=torch.float64)]
# 결과값 : tensor([[-11.8243],
#         [-13.4833],
#         [-13.4562],
#         [-10.2105]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.174193857877981e-05
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017888888888888887, 0.0004444444444444444, 0.15666666666666668, 0.15666666666666668]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021333333333333334, 0.0018000000000000002, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015444444444444444, 0.0007222222222222223, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001477777777777778, 0.0012555555555555555, 0.023333333333333334, 0.023333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0018, 0.0021, 0.0015, 0.0015], dtype=torch.float64), tensor([0.0004, 0.0018, 0.0007, 0.0013], dtype=torch.float64), tensor([0.1567, 0.0300, 0.0267, 0.0233], dtype=torch.float64), tensor([0.1567, 0.0300, 0.0267, 0.0233], dtype=torch.float64)]
# 결과값 : tensor([[-16.7972],
#         [-13.1692],
#         [ -9.2880],
#         [-15.3000]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 2.3661974410060793e-05
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002022222222222222, 0.0011, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0013, 0.0010222222222222221, 0.056666666666666664, 0.056666666666666664]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.0006777777777777778, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001877777777777778, 0.0012111111111111112, 0.03333333333333333, 0.03333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0020, 0.0013, 0.0018, 0.0019], dtype=torch.float64), tensor([0.0011, 0.0010, 0.0007, 0.0012], dtype=torch.float64), tensor([0.0267, 0.0567, 0.0233, 0.0333], dtype=torch.float64), tensor([0.0267, 0.0567, 0.0233, 0.0333], dtype=torch.float64)]
# 결과값 : tensor([[-17.0240],
#         [-17.0440],
#         [-15.2198],
#         [-12.1425]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.4007055142428726e-06
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0016444444444444445, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006333333333333333, 0.0013222222222222222, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002611111111111111, 0.0018444444444444446, 0.33666666666666667, 0.33666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016555555555555555, 0.0015333333333333334, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0006, 0.0026, 0.0017], dtype=torch.float64), tensor([0.0016, 0.0013, 0.0018, 0.0015], dtype=torch.float64), tensor([0.0300, 0.0333, 0.3367, 0.0367], dtype=torch.float64), tensor([0.0300, 0.0333, 0.3367, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-14.7834],
#         [-11.1029],
#         [ -9.6473],
#         [-15.6229]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 2.002661130973138e-05
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002955555555555556, 0.0006777777777777778, 0.07666666666666666, 0.07666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0013222222222222222, 0.07666666666666666, 0.07666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0004888888888888889, 0.0006, 0.14333333333333334, 0.14333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0023, 0.0008666666666666667, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0030, 0.0017, 0.0005, 0.0023], dtype=torch.float64), tensor([0.0007, 0.0013, 0.0006, 0.0009], dtype=torch.float64), tensor([0.0767, 0.0767, 0.1433, 0.0267], dtype=torch.float64), tensor([0.0767, 0.0767, 0.1433, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-14.8238],
#         [-15.7330],
#         [-10.4831],
#         [-13.2114]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 7.569691206299467e-06
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.001288888888888889, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015666666666666665, 0.001011111111111111, 0.12, 0.12]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017222222222222224, 0.0015, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0011, 0.0028444444444444446, 0.09666666666666666, 0.09666666666666666]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0018, 0.0016, 0.0017, 0.0011], dtype=torch.float64), tensor([0.0013, 0.0010, 0.0015, 0.0028], dtype=torch.float64), tensor([0.0733, 0.1200, 0.0267, 0.0967], dtype=torch.float64), tensor([0.0733, 0.1200, 0.0267, 0.0967], dtype=torch.float64)]
# 결과값 : tensor([[-10.0070],
#         [-17.4685],
#         [-16.7613],
#         [-11.6146]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.3529990610550158e-05
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001822222222222222, 0.0010333333333333334, 0.016666666666666666, 0.016666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001588888888888889, 0.0014555555555555554, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0025666666666666667, 0.0018111111111111112, 0.17333333333333334, 0.17333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001411111111111111, 0.001388888888888889, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0018, 0.0016, 0.0026, 0.0014], dtype=torch.float64), tensor([0.0010, 0.0015, 0.0018, 0.0014], dtype=torch.float64), tensor([0.0167, 0.0433, 0.1733, 0.0267], dtype=torch.float64), tensor([0.0167, 0.0433, 0.1733, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-17.3651],
#         [-17.2896],
#         [-10.6230],
#         [-17.0480]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 6.079599643271649e-06
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006, 0.0006333333333333333, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0020555555555555557, 0.0011333333333333334, 0.3566666666666667, 0.3566666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0024111111111111113, 0.0005666666666666667, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001822222222222222, 0.0011111111111111111, 0.05333333333333334, 0.05333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0006, 0.0021, 0.0024, 0.0018], dtype=torch.float64), tensor([0.0006, 0.0011, 0.0006, 0.0011], dtype=torch.float64), tensor([0.0267, 0.3567, 0.0633, 0.0533], dtype=torch.float64), tensor([0.0267, 0.3567, 0.0633, 0.0533], dtype=torch.float64)]
# 결과값 : tensor([[-17.5721],
#         [-11.0043],
#         [-16.0341],
#         [-17.5246]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 4.202092441119021e-06
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0010666666666666667, 0.0012444444444444445, 0.07666666666666666, 0.07666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0024222222222222223, 0.0005888888888888889, 0.08, 0.08]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0008666666666666667, 0.0014, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003177777777777778, 0.0009777777777777777, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0011, 0.0024, 0.0009, 0.0032], dtype=torch.float64), tensor([0.0012, 0.0006, 0.0014, 0.0010], dtype=torch.float64), tensor([0.0767, 0.0800, 0.0267, 0.0367], dtype=torch.float64), tensor([0.0767, 0.0800, 0.0267, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-18.2314],
#         [-13.1433],
#         [-18.5673],
#         [-15.8156]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 5.066390258434694e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0024333333333333334, 0.0008888888888888888, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001388888888888889, 0.001588888888888889, 0.06, 0.06]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0010777777777777778, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014888888888888888, 0.0010333333333333334, 0.05333333333333334, 0.05333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0024, 0.0014, 0.0017, 0.0015], dtype=torch.float64), tensor([0.0009, 0.0016, 0.0011, 0.0010], dtype=torch.float64), tensor([0.0533, 0.0600, 0.0633, 0.0533], dtype=torch.float64), tensor([0.0533, 0.0600, 0.0633, 0.0533], dtype=torch.float64)]
# 결과값 : tensor([[-16.8181],
#         [-18.5202],
#         [-17.5174],
#         [-17.0735]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002788888888888889, 0.0005888888888888889, 0.08, 0.08]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0026777777777777776, 0.0011222222222222222, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017444444444444443, 0.0013444444444444443, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018333333333333335, 0.0009777777777777777, 0.016666666666666666, 0.016666666666666666]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0028, 0.0027, 0.0017, 0.0018], dtype=torch.float64), tensor([0.0006, 0.0011, 0.0013, 0.0010], dtype=torch.float64), tensor([0.0800, 0.0300, 0.0533, 0.0167], dtype=torch.float64), tensor([0.0800, 0.0300, 0.0533, 0.0167], dtype=torch.float64)]
# 결과값 : tensor([[-11.6346],
#         [-19.1502],
#         [-18.2994],
#         [-17.6511]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 2.205362079621409e-06
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021333333333333334, 0.0012, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018666666666666669, 0.0016444444444444445, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002488888888888889, 0.0011888888888888889, 0.056666666666666664, 0.056666666666666664]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018333333333333335, 0.0016444444444444445, 0.08666666666666667, 0.08666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0021, 0.0019, 0.0025, 0.0018], dtype=torch.float64), tensor([0.0012, 0.0016, 0.0012, 0.0016], dtype=torch.float64), tensor([0.0433, 0.0267, 0.0567, 0.0867], dtype=torch.float64), tensor([0.0433, 0.0267, 0.0567, 0.0867], dtype=torch.float64)]
# 결과값 : tensor([[-17.7942],
#         [-18.1911],
#         [-18.7600],
#         [-17.8338]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0004777777777777778, 0.0010777777777777778, 0.12666666666666668, 0.12666666666666668]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018888888888888887, 0.0011888888888888889, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014888888888888888, 0.0008111111111111112, 0.08, 0.08]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002711111111111111, 0.0008888888888888888, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0005, 0.0019, 0.0015, 0.0027], dtype=torch.float64), tensor([0.0011, 0.0012, 0.0008, 0.0009], dtype=torch.float64), tensor([0.1267, 0.0267, 0.0800, 0.0367], dtype=torch.float64), tensor([0.1267, 0.0267, 0.0800, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-16.7443],
#         [-17.9668],
#         [-18.1515],
#         [-19.4576]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006888888888888888, 0.0009333333333333334, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006666666666666668, 0.0010777777777777778, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006666666666666668, 0.00017777777777777779, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006666666666666668, 0.0012555555555555555, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0007, 0.0007, 0.0007, 0.0007], dtype=torch.float64), tensor([0.0009, 0.0011, 0.0002, 0.0013], dtype=torch.float64), tensor([0.0267, 0.0367, 0.0367, 0.0267], dtype=torch.float64), tensor([0.0267, 0.0367, 0.0367, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-18.7803],
#         [-19.0152],
#         [-17.4875],
#         [-18.0873]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016222222222222224, 0.001311111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018666666666666669, 0.0014444444444444446, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007555555555555555, 0.001711111111111111, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [5.555555555555555e-05, 0.0016222222222222224, 0.13, 0.13]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([1.6222e-03, 1.8667e-03, 7.5556e-04, 5.5556e-05], dtype=torch.float64), tensor([0.0013, 0.0014, 0.0017, 0.0016], dtype=torch.float64), tensor([0.0367, 0.0267, 0.0733, 0.1300], dtype=torch.float64), tensor([0.0367, 0.0267, 0.0733, 0.1300], dtype=torch.float64)]
# 결과값 : tensor([[-19.3006],
#         [-19.4729],
#         [-19.0501],
#         [-18.7120]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0026555555555555555, 0.0026777777777777776, 0.2, 0.2]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021, 0.0012444444444444445, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0009777777777777777, 0.0011777777777777778, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014555555555555554, 0.0014555555555555554, 0.05, 0.05]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0027, 0.0021, 0.0010, 0.0015], dtype=torch.float64), tensor([0.0027, 0.0012, 0.0012, 0.0015], dtype=torch.float64), tensor([0.2000, 0.0633, 0.0267, 0.0500], dtype=torch.float64), tensor([0.2000, 0.0633, 0.0267, 0.0500], dtype=torch.float64)]
# 결과값 : tensor([[-14.0872],
#         [-19.7214],
#         [-18.3219],
#         [-18.8927]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.7881387748275301e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015999999999999999, 0.0007111111111111111, 0.06666666666666667, 0.06666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0010777777777777778, 0.0013333333333333335, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003088888888888889, 0.0016222222222222224, 0.04666666666666667, 0.04666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001311111111111111, 0.0013555555555555556, 0.09, 0.09]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0011, 0.0031, 0.0013], dtype=torch.float64), tensor([0.0007, 0.0013, 0.0016, 0.0014], dtype=torch.float64), tensor([0.0667, 0.0300, 0.0467, 0.0900], dtype=torch.float64), tensor([0.0667, 0.0300, 0.0467, 0.0900], dtype=torch.float64)]
# 결과값 : tensor([[-18.9973],
#         [-17.7047],
#         [-18.3726],
#         [-18.6697]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003211111111111111, 0.0018999999999999998, 0.33666666666666667, 0.33666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017888888888888887, 0.001411111111111111, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014333333333333333, 0.0015555555555555557, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001822222222222222, 0.002288888888888889, 0.13, 0.13]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0032, 0.0018, 0.0014, 0.0018], dtype=torch.float64), tensor([0.0019, 0.0014, 0.0016, 0.0023], dtype=torch.float64), tensor([0.3367, 0.0333, 0.0233, 0.1300], dtype=torch.float64), tensor([0.3367, 0.0333, 0.0233, 0.1300], dtype=torch.float64)]
# 결과값 : tensor([[-18.4090],
#         [-18.2930],
#         [-18.9822],
#         [-12.9930]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 5.662435000886035e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0027, 0.0006888888888888888, 0.17333333333333334, 0.17333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0023888888888888887, 0.0011111111111111111, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002, 0.0013666666666666666, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.001411111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0027, 0.0024, 0.0020, 0.0018], dtype=torch.float64), tensor([0.0007, 0.0011, 0.0014, 0.0014], dtype=torch.float64), tensor([0.1733, 0.0233, 0.0333, 0.0367], dtype=torch.float64), tensor([0.1733, 0.0233, 0.0333, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-18.6075],
#         [-19.4861],
#         [-17.4456],
#         [-19.1677]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007222222222222223, 0.0010777777777777778, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002111111111111111, 0.0014666666666666667, 0.06666666666666667, 0.06666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0004444444444444444, 0.0013555555555555556, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0018111111111111112, 0.05, 0.05]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0007, 0.0021, 0.0004, 0.0017], dtype=torch.float64), tensor([0.0011, 0.0015, 0.0014, 0.0018], dtype=torch.float64), tensor([0.0367, 0.0667, 0.0367, 0.0500], dtype=torch.float64), tensor([0.0367, 0.0667, 0.0367, 0.0500], dtype=torch.float64)]
# 결과값 : tensor([[-19.1586],
#         [-18.9349],
#         [-19.5952],
#         [-17.7516]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0011111111111111111, 0.0015333333333333334, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.000911111111111111, 0.0016777777777777776, 0.08666666666666667, 0.08666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0018999999999999998, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015999999999999999, 0.0018111111111111112, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0011, 0.0009, 0.0017, 0.0016], dtype=torch.float64), tensor([0.0015, 0.0017, 0.0019, 0.0018], dtype=torch.float64), tensor([0.0433, 0.0867, 0.0367, 0.0367], dtype=torch.float64), tensor([0.0433, 0.0867, 0.0367, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-19.7731],
#         [-19.3898],
#         [-19.6243],
#         [-18.4888]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0026888888888888887, 0.0013333333333333335, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018000000000000002, 0.0007333333333333333, 0.22666666666666666, 0.22666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0027555555555555554, 0.0015555555555555557, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021, 0.0021555555555555555, 0.03, 0.03]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0027, 0.0018, 0.0028, 0.0021], dtype=torch.float64), tensor([0.0013, 0.0007, 0.0016, 0.0022], dtype=torch.float64), tensor([0.0300, 0.2267, 0.0733, 0.0300], dtype=torch.float64), tensor([0.0300, 0.2267, 0.0733, 0.0300], dtype=torch.float64)]
# 결과값 : tensor([[-18.7414],
#         [-20.1065],
#         [-18.7521],
#         [-19.0689]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016666666666666668, 0.0016333333333333332, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0013777777777777777, 0.001588888888888889, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0013222222222222222, 0.0007777777777777778, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.001411111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0014, 0.0013, 0.0016], dtype=torch.float64), tensor([0.0016, 0.0016, 0.0008, 0.0014], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0533, 0.0367], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0533, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-19.4988],
#         [-21.6828],
#         [-18.7856],
#         [-17.5692]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018888888888888887, 0.002022222222222222, 0.02, 0.02]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012777777777777779, 0.0011666666666666665, 0.15333333333333332, 0.15333333333333332]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017444444444444443, 0.002288888888888889, 0.06, 0.06]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007555555555555555, 0.0007333333333333333, 0.023333333333333334, 0.023333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0019, 0.0013, 0.0017, 0.0008], dtype=torch.float64), tensor([0.0020, 0.0012, 0.0023, 0.0007], dtype=torch.float64), tensor([0.0200, 0.1533, 0.0600, 0.0233], dtype=torch.float64), tensor([0.0200, 0.1533, 0.0600, 0.0233], dtype=torch.float64)]
# 결과값 : tensor([[-19.6844],
#         [-15.6062],
#         [-19.2824],
#         [-18.8289]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 2.9802320611338473e-08
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002333333333333333, 9.999999999999999e-05, 0.17666666666666667, 0.17666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.00018888888888888888, 0.001411111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0005666666666666667, 0.0015666666666666665, 0.04, 0.04]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002011111111111111, 0.0027222222222222222, 0.07333333333333333, 0.07333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0023, 0.0002, 0.0006, 0.0020], dtype=torch.float64), tensor([1.0000e-04, 1.4111e-03, 1.5667e-03, 2.7222e-03], dtype=torch.float64), tensor([0.1767, 0.0367, 0.0400, 0.0733], dtype=torch.float64), tensor([0.1767, 0.0367, 0.0400, 0.0733], dtype=torch.float64)]
# 결과값 : tensor([[-20.0290],
#         [-19.3492],
#         [-18.2782],
#         [-21.2611]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001877777777777778, 0.0012777777777777779, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018000000000000002, 0.000988888888888889, 0.016666666666666666, 0.016666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0011555555555555555, 0.0026, 0.14666666666666667, 0.14666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018999999999999998, 0.0013666666666666666, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0019, 0.0018, 0.0012, 0.0019], dtype=torch.float64), tensor([0.0013, 0.0010, 0.0026, 0.0014], dtype=torch.float64), tensor([0.0433, 0.0167, 0.1467, 0.0267], dtype=torch.float64), tensor([0.0433, 0.0167, 0.1467, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-20.5345],
#         [-19.5262],
#         [-12.5028],
#         [-20.4269]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 9.238702887159889e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007333333333333333, 0.0010666666666666667, 0.11666666666666667, 0.11666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0022555555555555554, 0.0018444444444444446, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016222222222222224, 0.0015222222222222221, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001411111111111111, 0.0007222222222222223, 0.10666666666666667, 0.10666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0007, 0.0023, 0.0016, 0.0014], dtype=torch.float64), tensor([0.0011, 0.0018, 0.0015, 0.0007], dtype=torch.float64), tensor([0.1167, 0.0300, 0.0333, 0.1067], dtype=torch.float64), tensor([0.1167, 0.0300, 0.0333, 0.1067], dtype=torch.float64)]
# 결과값 : tensor([[-21.8981],
#         [-18.6749],
#         [-20.7812],
#         [-20.7462]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0010888888888888888, 0.08666666666666667, 0.08666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001, 0.0013444444444444443, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001511111111111111, 0.0012444444444444445, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012555555555555555, 0.0013777777777777777, 0.03, 0.03]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0010, 0.0015, 0.0013], dtype=torch.float64), tensor([0.0011, 0.0013, 0.0012, 0.0014], dtype=torch.float64), tensor([0.0867, 0.0233, 0.0267, 0.0300], dtype=torch.float64), tensor([0.0867, 0.0233, 0.0267, 0.0300], dtype=torch.float64)]
# 결과값 : tensor([[-19.7978],
#         [-19.3024],
#         [-19.9012],
#         [-19.3228]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012666666666666666, 0.0020444444444444442, 0.10666666666666667, 0.10666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014333333333333333, 0.0010555555555555555, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018999999999999998, 0.0015222222222222221, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018888888888888887, 0.0015555555555555557, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0013, 0.0014, 0.0019, 0.0019], dtype=torch.float64), tensor([0.0020, 0.0011, 0.0015, 0.0016], dtype=torch.float64), tensor([0.1067, 0.0533, 0.0367, 0.0267], dtype=torch.float64), tensor([0.1067, 0.0533, 0.0367, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-18.9355],
#         [-20.1043],
#         [-20.2582],
#         [-20.4986]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016666666666666668, 0.001288888888888889, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.0014, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0025666666666666667, 0.0002888888888888889, 0.31, 0.31]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015333333333333334, 0.0012777777777777779, 0.043333333333333335, 0.043333333333333335]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0016, 0.0026, 0.0015], dtype=torch.float64), tensor([0.0013, 0.0014, 0.0003, 0.0013], dtype=torch.float64), tensor([0.0433, 0.0367, 0.3100, 0.0433], dtype=torch.float64), tensor([0.0433, 0.0367, 0.3100, 0.0433], dtype=torch.float64)]
# 결과값 : tensor([[-19.7894],
#         [-20.2125],
#         [-14.5865],
#         [-20.4991]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.1920926112907182e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0019333333333333331, 0.0007333333333333333, 0.17333333333333334, 0.17333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003177777777777778, 0.0009777777777777777, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0019333333333333331, 0.0013333333333333335, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016666666666666668, 0.001411111111111111, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0019, 0.0032, 0.0019, 0.0017], dtype=torch.float64), tensor([0.0007, 0.0010, 0.0013, 0.0014], dtype=torch.float64), tensor([0.1733, 0.0367, 0.0433, 0.0267], dtype=torch.float64), tensor([0.1733, 0.0367, 0.0433, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-15.2739],
#         [-21.0862],
#         [-19.9124],
#         [-20.3642]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 5.960463766996327e-08
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.0012444444444444445, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0005888888888888889, 0.0011, 0.05, 0.05]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0019333333333333331, 0.0010222222222222221, 0.08, 0.08]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015555555555555557, 0.0006, 0.03333333333333333, 0.03333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0006, 0.0019, 0.0016], dtype=torch.float64), tensor([0.0012, 0.0011, 0.0010, 0.0006], dtype=torch.float64), tensor([0.0433, 0.0500, 0.0800, 0.0333], dtype=torch.float64), tensor([0.0433, 0.0500, 0.0800, 0.0333], dtype=torch.float64)]
# 결과값 : tensor([[-20.6565],
#         [-19.1443],
#         [-19.4517],
#         [-19.1598]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002033333333333333, 0.0007777777777777778, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012555555555555555, 0.0013444444444444443, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.0009777777777777777, 0.09666666666666666, 0.09666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003022222222222222, 0.0014333333333333333, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0020, 0.0013, 0.0018, 0.0030], dtype=torch.float64), tensor([0.0008, 0.0013, 0.0010, 0.0014], dtype=torch.float64), tensor([0.0633, 0.0367, 0.0967, 0.0267], dtype=torch.float64), tensor([0.0633, 0.0367, 0.0967, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-19.4784],
#         [-19.9876],
#         [-14.3590],
#         [-18.8432]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 1.4901156930591242e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0025555555555555557, 0.0016555555555555555, 0.11333333333333333, 0.11333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0005111111111111111, 0.00043333333333333337, 0.04666666666666667, 0.04666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021222222222222224, 6.666666666666667e-05, 0.3233333333333333, 0.3233333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0028777777777777777, 0.0025444444444444442, 0.15, 0.15]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0026, 0.0005, 0.0021, 0.0029], dtype=torch.float64), tensor([1.6556e-03, 4.3333e-04, 6.6667e-05, 2.5444e-03], dtype=torch.float64), tensor([0.1133, 0.0467, 0.3233, 0.1500], dtype=torch.float64), tensor([0.1133, 0.0467, 0.3233, 0.1500], dtype=torch.float64)]
# 결과값 : tensor([[-20.2147],
#         [-19.5257],
#         [-12.7834],
#         [-20.4917]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 7.15254714123148e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001388888888888889, 0.001877777777777778, 0.056666666666666664, 0.056666666666666664]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016111111111111111, 0.0010777777777777778, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0013777777777777777, 0.0013, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0001666666666666667, 0.14333333333333334, 0.14333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0014, 0.0016, 0.0014, 0.0017], dtype=torch.float64), tensor([0.0019, 0.0011, 0.0013, 0.0002], dtype=torch.float64), tensor([0.0567, 0.0733, 0.0267, 0.1433], dtype=torch.float64), tensor([0.0567, 0.0733, 0.0267, 0.1433], dtype=torch.float64)]
# 결과값 : tensor([[-16.6890],
#         [-21.6486],
#         [-19.3068],
#         [-19.8671]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0022444444444444443, 0.0012222222222222222, 0.04, 0.04]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002322222222222222, 0.0009000000000000001, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.0015666666666666665, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007888888888888889, 0.0014444444444444446, 0.11666666666666667, 0.11666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0022, 0.0023, 0.0018, 0.0008], dtype=torch.float64), tensor([0.0012, 0.0009, 0.0016, 0.0014], dtype=torch.float64), tensor([0.0400, 0.0233, 0.0267, 0.1167], dtype=torch.float64), tensor([0.0400, 0.0233, 0.0267, 0.1167], dtype=torch.float64)]
# 결과값 : tensor([[-20.6554],
#         [-16.9963],
#         [-20.6632],
#         [-21.2465]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0029666666666666665, 0.00039999999999999996, 0.18666666666666668, 0.18666666666666668]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0015, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0031555555555555555, 0.00035555555555555557, 0.14333333333333334, 0.14333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0031888888888888887, 0.001288888888888889, 0.03333333333333333, 0.03333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0030, 0.0017, 0.0032, 0.0032], dtype=torch.float64), tensor([0.0004, 0.0015, 0.0004, 0.0013], dtype=torch.float64), tensor([0.1867, 0.0333, 0.1433, 0.0333], dtype=torch.float64), tensor([0.1867, 0.0333, 0.1433, 0.0333], dtype=torch.float64)]
# 결과값 : tensor([[-20.0408],
#         [-20.7370],
#         [-19.7056],
#         [-20.3264]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0016777777777777776, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014, 0.0018000000000000002, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002533333333333333, 7.777777777777778e-05, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018333333333333335, 0.0011111111111111111, 0.023333333333333334, 0.023333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0014, 0.0025, 0.0018], dtype=torch.float64), tensor([1.6778e-03, 1.8000e-03, 7.7778e-05, 1.1111e-03], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0267, 0.0233], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0267, 0.0233], dtype=torch.float64)]
# 결과값 : tensor([[-18.3976],
#         [-20.7776],
#         [-21.3709],
#         [-20.3286]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017888888888888887, 0.0020555555555555557, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0028444444444444446, 0.0006888888888888888, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0011555555555555555, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018666666666666669, 0.0018999999999999998, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0018, 0.0028, 0.0017, 0.0019], dtype=torch.float64), tensor([0.0021, 0.0007, 0.0012, 0.0019], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0267, 0.0367], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0267, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-19.7632],
#         [-19.0330],
#         [-19.3210],
#         [-18.4427]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0003222222222222222, 0.0025555555555555557, 0.02, 0.02]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.00039999999999999996, 0.0006555555555555555, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012111111111111112, 0.0013666666666666666, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001688888888888889, 0.0016444444444444445, 0.023333333333333334, 0.023333333333333334]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0003, 0.0004, 0.0012, 0.0017], dtype=torch.float64), tensor([0.0026, 0.0007, 0.0014, 0.0016], dtype=torch.float64), tensor([0.0200, 0.0233, 0.0633, 0.0233], dtype=torch.float64), tensor([0.0200, 0.0233, 0.0633, 0.0233], dtype=torch.float64)]
# 결과값 : tensor([[-21.1719],
#         [-18.4933],
#         [-19.2924],
#         [-20.3088]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003122222222222222, 0.0006777777777777778, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002622222222222222, 0.0016666666666666668, 0.09, 0.09]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0013666666666666666, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015444444444444444, 0.0013, 0.06333333333333334, 0.06333333333333334]
# label : 0
# ...
# 얼굴 좌표값 : [0.000911111111111111, 0.0016777777777777776, 0.08666666666666667, 0.08666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0014, 0.0013, 0.0018, 0.0009], dtype=torch.float64), tensor([0.0018, 0.0013, 0.0016, 0.0017], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0867, 0.0867], dtype=torch.float64), tensor([0.0367, 0.0367, 0.0867, 0.0867], dtype=torch.float64)]
# 결과값 : tensor([[-20.6887],
#         [-17.6094],
#         [-20.6862],
#         [-20.1189]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0004444444444444444, 0.0013555555555555556, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007888888888888889, 0.0014444444444444446, 0.11666666666666667, 0.11666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0011555555555555555, 0.0026, 0.14666666666666667, 0.14666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018999999999999998, 0.0015222222222222221, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0004, 0.0008, 0.0012, 0.0019], dtype=torch.float64), tensor([0.0014, 0.0014, 0.0026, 0.0015], dtype=torch.float64), tensor([0.0367, 0.1167, 0.1467, 0.0367], dtype=torch.float64), tensor([0.0367, 0.1167, 0.1467, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-21.4186],
#         [-18.3539],
#         [-13.1565],
#         [-19.9006]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 4.768367034557741e-07
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017444444444444443, 0.0013777777777777777, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0012777777777777779, 0.0011666666666666665, 0.15333333333333332, 0.15333333333333332]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016666666666666668, 0.001411111111111111, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014555555555555554, 0.0014555555555555554, 0.05, 0.05]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0013, 0.0017, 0.0015], dtype=torch.float64), tensor([0.0014, 0.0012, 0.0014, 0.0015], dtype=torch.float64), tensor([0.0367, 0.1533, 0.0267, 0.0500], dtype=torch.float64), tensor([0.0367, 0.1533, 0.0267, 0.0500], dtype=torch.float64)]
# 결과값 : tensor([[-17.2535],
#         [-20.3903],
#         [-19.1161],
#         [-17.8400]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015999999999999999, 0.0007111111111111111, 0.06666666666666667, 0.06666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018999999999999998, 0.0012777777777777779, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.00018888888888888888, 0.001411111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0006666666666666668, 0.00017777777777777779, 0.03666666666666667, 0.03666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0019, 0.0002, 0.0007], dtype=torch.float64), tensor([0.0007, 0.0013, 0.0014, 0.0002], dtype=torch.float64), tensor([0.0667, 0.0367, 0.0367, 0.0367], dtype=torch.float64), tensor([0.0667, 0.0367, 0.0367, 0.0367], dtype=torch.float64)]
# 결과값 : tensor([[-22.1662],
#         [-21.0375],
#         [-21.0727],
#         [-20.6350]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001311111111111111, 0.0013555555555555556, 0.09, 0.09]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002011111111111111, 0.0027222222222222222, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0010222222222222221, 0.0002222222222222222, 0.08333333333333333, 0.08333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0021333333333333334, 0.0012, 0.043333333333333335, 0.043333333333333335]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0013, 0.0020, 0.0010, 0.0021], dtype=torch.float64), tensor([0.0014, 0.0027, 0.0002, 0.0012], dtype=torch.float64), tensor([0.0900, 0.0733, 0.0833, 0.0433], dtype=torch.float64), tensor([0.0900, 0.0733, 0.0833, 0.0433], dtype=torch.float64)]
# 결과값 : tensor([[-19.4129],
#         [-20.8049],
#         [-21.0030],
#         [-20.8081]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0001111111111111111, 0.0008222222222222222, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017777777777777776, 0.001511111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0010666666666666667, 0.0012444444444444445, 0.07666666666666666, 0.07666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002111111111111111, 0.0014666666666666667, 0.06666666666666667, 0.06666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0001, 0.0018, 0.0011, 0.0021], dtype=torch.float64), tensor([0.0008, 0.0015, 0.0012, 0.0015], dtype=torch.float64), tensor([0.0433, 0.0367, 0.0767, 0.0667], dtype=torch.float64), tensor([0.0433, 0.0367, 0.0767, 0.0667], dtype=torch.float64)]
# 결과값 : tensor([[-20.3757],
#         [-19.9786],
#         [-21.0932],
#         [-21.3195]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002022222222222222, 0.0011, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002533333333333333, 7.777777777777778e-05, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002033333333333333, 0.0007777777777777778, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0007333333333333333, 0.0010666666666666667, 0.11666666666666667, 0.11666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0020, 0.0025, 0.0020, 0.0007], dtype=torch.float64), tensor([1.1000e-03, 7.7778e-05, 7.7778e-04, 1.0667e-03], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0633, 0.1167], dtype=torch.float64), tensor([0.0267, 0.0267, 0.0633, 0.1167], dtype=torch.float64)]
# 결과값 : tensor([[-21.2398],
#         [-20.6803],
#         [-20.7982],
#         [-20.6966]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0003222222222222222, 0.0025555555555555557, 0.02, 0.02]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002711111111111111, 0.0008888888888888888, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0029666666666666665, 0.00039999999999999996, 0.18666666666666668, 0.18666666666666668]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001388888888888889, 0.001877777777777778, 0.056666666666666664, 0.056666666666666664]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0003, 0.0027, 0.0030, 0.0014], dtype=torch.float64), tensor([0.0026, 0.0009, 0.0004, 0.0019], dtype=torch.float64), tensor([0.0200, 0.0367, 0.1867, 0.0567], dtype=torch.float64), tensor([0.0200, 0.0367, 0.1867, 0.0567], dtype=torch.float64)]
# 결과값 : tensor([[-20.8810],
#         [-20.1563],
#         [-19.5638],
#         [-21.1622]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0024111111111111113, 0.0005666666666666667, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0015, 0.03333333333333333, 0.03333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014888888888888888, 0.0010333333333333334, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0010888888888888888, 0.08666666666666667, 0.08666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0024, 0.0017, 0.0015, 0.0017], dtype=torch.float64), tensor([0.0006, 0.0015, 0.0010, 0.0011], dtype=torch.float64), tensor([0.0633, 0.0333, 0.0533, 0.0867], dtype=torch.float64), tensor([0.0633, 0.0333, 0.0533, 0.0867], dtype=torch.float64)]
# 결과값 : tensor([[-19.5912],
#         [-21.1681],
#         [-21.0505],
#         [-20.5618]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0023, 0.0008666666666666667, 0.02666666666666667, 0.02666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017444444444444443, 0.002288888888888889, 0.06, 0.06]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017555555555555553, 0.001288888888888889, 0.07333333333333333, 0.07333333333333333]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002322222222222222, 0.0009333333333333334, 0.04, 0.04]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0023, 0.0017, 0.0018, 0.0023], dtype=torch.float64), tensor([0.0009, 0.0023, 0.0013, 0.0009], dtype=torch.float64), tensor([0.0267, 0.0600, 0.0733, 0.0400], dtype=torch.float64), tensor([0.0267, 0.0600, 0.0733, 0.0400], dtype=torch.float64)]
# 결과값 : tensor([[-20.8985],
#         [-20.6839],
#         [-19.1097],
#         [-20.4915]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.003177777777777778, 0.0009777777777777777, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0011111111111111111, 0.0015333333333333334, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001822222222222222, 0.0010333333333333334, 0.016666666666666666, 0.016666666666666666]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015444444444444444, 0.0013777777777777777, 0.03, 0.03]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0032, 0.0011, 0.0018, 0.0015], dtype=torch.float64), tensor([0.0010, 0.0015, 0.0010, 0.0014], dtype=torch.float64), tensor([0.0367, 0.0433, 0.0167, 0.0300], dtype=torch.float64), tensor([0.0367, 0.0433, 0.0167, 0.0300], dtype=torch.float64)]
# 결과값 : tensor([[-21.2183],
#         [-19.8184],
#         [-20.2613],
#         [-19.4542]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0031999999999999997, 0.0009444444444444444, 0.06, 0.06]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.000911111111111111, 0.05333333333333334, 0.05333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0030444444444444442, 0.0015999999999999999, 0.02, 0.02]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015555555555555557, 0.0006, 0.03333333333333333, 0.03333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0032, 0.0016, 0.0030, 0.0016], dtype=torch.float64), tensor([0.0009, 0.0009, 0.0016, 0.0006], dtype=torch.float64), tensor([0.0600, 0.0533, 0.0200, 0.0333], dtype=torch.float64), tensor([0.0600, 0.0533, 0.0200, 0.0333], dtype=torch.float64)]
# 결과값 : tensor([[-20.8636],
#         [-20.2754],
#         [-20.0399],
#         [-18.1643]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001588888888888889, 0.0014555555555555554, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016222222222222224, 0.001311111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0017000000000000001, 0.0001666666666666667, 0.14333333333333334, 0.14333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0004777777777777778, 0.0010777777777777778, 0.12666666666666668, 0.12666666666666668]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0016, 0.0017, 0.0005], dtype=torch.float64), tensor([0.0015, 0.0013, 0.0002, 0.0011], dtype=torch.float64), tensor([0.0433, 0.0367, 0.1433, 0.1267], dtype=torch.float64), tensor([0.0433, 0.0367, 0.1433, 0.1267], dtype=torch.float64)]
# 결과값 : tensor([[-21.1085],
#         [-21.3344],
#         [-21.6053],
#         [-21.9390]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0005666666666666667, 0.0015666666666666665, 0.04, 0.04]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015999999999999999, 0.0018111111111111112, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016777777777777776, 0.0016444444444444445, 0.03, 0.03]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016111111111111111, 0.0010777777777777778, 0.07333333333333333, 0.07333333333333333]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0006, 0.0016, 0.0017, 0.0016], dtype=torch.float64), tensor([0.0016, 0.0018, 0.0016, 0.0011], dtype=torch.float64), tensor([0.0400, 0.0367, 0.0300, 0.0733], dtype=torch.float64), tensor([0.0400, 0.0367, 0.0300, 0.0733], dtype=torch.float64)]
# 결과값 : tensor([[-21.1192],
#         [-19.9811],
#         [-21.1025],
#         [-21.3449]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016333333333333332, 0.001411111111111111, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0014333333333333333, 0.0015555555555555557, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018666666666666669, 0.0018999999999999998, 0.03666666666666667, 0.03666666666666667]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.001011111111111111, 5.555555555555555e-05, 0.05, 0.05]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0016, 0.0014, 0.0019, 0.0010], dtype=torch.float64), tensor([1.4111e-03, 1.5556e-03, 1.9000e-03, 5.5556e-05], dtype=torch.float64), tensor([0.0367, 0.0233, 0.0367, 0.0500], dtype=torch.float64), tensor([0.0367, 0.0233, 0.0367, 0.0500], dtype=torch.float64)]
# 결과값 : tensor([[-19.6085],
#         [-20.5765],
#         [-21.5635],
#         [-20.0347]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0016666666666666668, 0.001288888888888889, 0.043333333333333335, 0.043333333333333335]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.002322222222222222, 0.0009000000000000001, 0.023333333333333334, 0.023333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0018888888888888887, 0.0011555555555555555, 0.06333333333333334, 0.06333333333333334]
# label : 0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0015444444444444444, 0.0007222222222222223, 0.02666666666666667, 0.02666666666666667]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0017, 0.0023, 0.0019, 0.0015], dtype=torch.float64), tensor([0.0013, 0.0009, 0.0012, 0.0007], dtype=torch.float64), tensor([0.0433, 0.0233, 0.0633, 0.0267], dtype=torch.float64), tensor([0.0433, 0.0233, 0.0633, 0.0267], dtype=torch.float64)]
# 결과값 : tensor([[-21.3981],
#         [-19.2867],
#         [-20.2407],
#         [-20.8558]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])
# loss : 0.0
# Original Image size: (300, 300, 3)
# 얼굴 좌표값 : [0.0026777777777777776, 0.0011222222222222222, 0.03, 0.03]
# label : 0
# 얼굴 좌표값(훈련) : [tensor([0.0027], dtype=torch.float64), tensor([0.0011], dtype=torch.float64), tensor([0.0300], dtype=torch.float64), tensor([0.0300], dtype=torch.float64)]
# 결과값 : tensor([[-20.7950]], grad_fn=<AddmmBackward0>)
# labels : tensor([[0.]])
# loss : 0.0

# %% [markdown]
# Swin transformer 모델 적용

# %%
import torch
from timm import create_model

swin_model = create_model('swin_base_patch4_window7_224', pretrained=False, num_classes=1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
swin_model.to(device)

# 저장된 모델 가중치 불러오기
swin_model.load_state_dict(torch.load('swin_model_ver3.pt', map_location=device))
swin_model.eval()
# Out:
# SwinTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (layers): Sequential(
#     (0): SwinTransformerStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=128, out_features=384, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=128, out_features=128, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=128, out_features=512, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=512, out_features=128, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=128, out_features=384, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=128, out_features=128, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.004)
#           (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=128, out_features=512, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=512, out_features=128, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.004)
#         )
#       )
#     )
#     (1): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=512, out_features=256, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=256, out_features=768, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.009)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.009)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=256, out_features=768, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.013)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.013)
#         )
#       )
#     )
#     (2): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=1024, out_features=512, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.017)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.017)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.022)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.022)
#         )
#         (2): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.026)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.026)
#         )
#         (3): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.030)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.030)
#         )
#         (4): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.035)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.035)
#         )
#         (5): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.039)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.039)
#         )
#         (6): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.043)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.043)
#         )
#         (7): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.048)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.048)
#         )
#         (8): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.052)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.052)
#         )
#         (9): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.057)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.057)
#         )
#         (10): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.061)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.061)
#         )
#         (11): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.065)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.065)
#         )
#         (12): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.070)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.070)
#         )
#         (13): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.074)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.074)
#         )
#         (14): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.078)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.078)
#         )
#         (15): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.083)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.083)
#         )
#         (16): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.087)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.087)
#         )
#         (17): SwinTransformerBlock(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.091)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.091)
#         )
#       )
#     )
#     (3): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.096)
#           (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.096)
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path1): DropPath(drop_prob=0.100)
#           (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.100)
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Identity())
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=1024, out_features=1, bias=True)
#     (flatten): Identity()
#   )
# )

# %%
import torch
import torchvision.transforms as T
import cv2
from PIL import Image
import numpy as np

# 모델 불러오기
swin_model = create_model('swin_base_patch4_window7_224', pretrained=False, num_classes=1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
swin_model.load_state_dict(torch.load('swin_model_ver3.pt', map_location=device))
swin_model.eval()
swin_model.to(device)

# 이미지 경로
image_path = './images/248.jpg'

# 이미지 전처리
transform = T.Compose([T.Resize((224, 224)), T.ToTensor()])
image = Image.open(image_path).convert('RGB')
input_image = transform(image).unsqueeze(0).to(device)

with torch.no_grad():
    output = swin_model(input_image)

probability = torch.sigmoid(output)

# 얼굴 좌표 추출
if len(probability) > 0:
    face_coords = probability[0].detach().cpu().numpy()

    if len(face_coords.shape) == 0:
        face_coords = face_coords.reshape(1)

    if len(face_coords) == 1:
        x, y, w, h = int(face_coords[0]), 0, 0, 0 
    else:
        x_scaled, y_scaled, size_x_scaled, size_y_scaled = face_coords
        x = int(x_scaled * image.width)
        y = int(y_scaled * image.height)
        w = int(size_x_scaled * image.width)
        h = int(size_y_scaled * image.height)

    image_np = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    cv2.rectangle(image_np, (x, y), (x + w, y + h), (0, 0, 255), 2)

    cv2.imshow('Image with Face Detection', image_np)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# 테스트 데이터셋 생성
test_face_dataset = FaceDataset(config['test'], transform=transform)
test_dataloader = DataLoader(test_face_dataset, batch_size=4, shuffle=False, num_workers=0)

# 모델 평가
swin_model.eval()
correct_predictions = 0
total_samples = 0

with torch.no_grad():
    for resized_images, face_images, labels in test_dataloader:
        resized_images, labels = resized_images.to(device), labels.to(device)

        # 모델 예측
        outputs = swin_model(face_images)

        # 예측된 결과를 기반으로 정확도 계산
        predictions = torch.round(torch.sigmoid(outputs))
        correct_predictions += (predictions == labels.unsqueeze(1)).sum().item()
        total_samples += labels.size(0)

# 정확도 계산
accuracy = correct_predictions / total_samples
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# %%
# DETR 모델 적용

import torch
import numpy as np
import cv2
import time
from ultralytics import RTDETR
import supervision as sv
class DETRClass:
    def __init__(self, capture_index):
        self.capture_index=capture_index
        self.device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = RTDETR('rtdetr-l.pt')
        self.CLASS_NAMES_DICT=self.model.model.names
        self.box_annotator=sv.BoxAnnotator(sv.ColorPalette.default(),thickness=3, text_thickness=3, text_scale=1.5)
    def plot_bboxs(self, results, frame):
        boxes=results[0].boxes.cpu().numpy()
        class_id=boxes.cls
        conf=boxes.conf
        xyxy=boxes.xyxy
        class_id=class_id.astype(np.int32)
        detections=sv.Detections(xyxy=xyxy, class_id=class_id, confidence=conf)
        self.labels = [f"{self.CLASS_NAMES_DICT[class_id]} {confidence: .2f}" for xyxy, class_id, confidence in zip(detections.xyxy, detections.class_id, detections.confidence)]
        frame=self.box_annotator.annotate(frame, detections, self.labels)
        return frame
    def __call__(self):
        cap=cv2.VideoCapture(self.capture_index)
        assert cap.isOpened()
        cap.set(cv2.CAP_PROP_FRAME_WIDTH,1280)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT,720)
        while cap.isOpened():
            start_time=time.perf_counter()
            ret, frame=cap.read()
            results=self.model.predict(frame)
            frame=self.plot_bboxs(results, frame)
            end_time=time.perf_counter()
            fps=1/(end_time-start_time)
            cv2.putText(frame, f"FPS: {fps:.2f}",(20,70), cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,1,(0,255,0),2)
            cv2.imshow("DETR",frame)
            if cv2.waitKey(1)==ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()
trasformer_detector=DETRClass(0)
trasformer_detector()
